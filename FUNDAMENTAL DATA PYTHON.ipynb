# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
symbol = 'BDMN.JK'
stock = yf.Ticker(symbol)

# %%
stock.info
# Out:
# {'address1': 'Menara Bank Danamon',
#  'address2': 'Jalan HR. Rasuna Said Block C No. 10, Kelurahan Karet Kecamatan Setiabudi',
#  'city': 'Jakarta',
#  'zip': '12920',
#  'country': 'Indonesia',
#  'phone': '62 21 8064 5000',
#  'fax': '62 21 8064 5033',
#  'website': 'https://www.danamon.co.id',
#  'industry': 'Banks—Regional',
#  'industryDisp': 'Banks—Regional',
#  'sector': 'Financial Services',
#  'sectorDisp': 'Financial Services',
# ...

# %%
stock.history(period='1mo')
# Out:
#                              Open    High     Low   Close   Volume  Dividends  \
# Date
# 2023-08-14 00:00:00+07:00  3020.0  3020.0  2980.0  3000.0  1916100        0.0
# 2023-08-15 00:00:00+07:00  3020.0  3050.0  3000.0  3010.0  3118700        0.0
# 2023-08-16 00:00:00+07:00  3010.0  3030.0  2990.0  3000.0  1527800        0.0
# 2023-08-18 00:00:00+07:00  3000.0  3020.0  2980.0  3000.0  1013100        0.0
# 2023-08-21 00:00:00+07:00  3000.0  3020.0  2920.0  2970.0  3699000        0.0
# 2023-08-22 00:00:00+07:00  2970.0  2980.0  2930.0  2940.0  2349400        0.0
# 2023-08-23 00:00:00+07:00  2930.0  2950.0  2930.0  2940.0  2663200        0.0
# 2023-08-24 00:00:00+07:00  2970.0  2970.0  2920.0  2940.0  1076300        0.0
# 2023-08-25 00:00:00+07:00  2950.0  2950.0  2930.0  2930.0   997600        0.0
# 2023-08-28 00:00:00+07:00  2940.0  2960.0  2900.0  2930.0  2052400        0.0
# 2023-08-29 00:00:00+07:00  2940.0  2950.0  2920.0  2930.0  1690200        0.0
# ...

# %%
df = stock.history(period="max")

# %%
df.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2003-01-22 00:00:00+07:00  557.354499  557.354499  509.920038  533.637268
# 2003-01-23 00:00:00+07:00  509.920142  521.778759  498.061554  498.061554
# 2003-01-24 00:00:00+07:00  474.344211  474.344211  462.485626  462.485626
# 2003-01-27 00:00:00+07:00  450.626955  450.626955  438.768341  438.768341
# 2003-01-28 00:00:00+07:00  426.909882  426.909882  415.051265  426.909882
#
#                            Volume  Dividends  Stock Splits
# Date
# 2003-01-22 00:00:00+07:00   66939        0.0           0.0
# 2003-01-23 00:00:00+07:00   60760        0.0           0.0
# 2003-01-24 00:00:00+07:00  418115        0.0           0.0
# 2003-01-27 00:00:00+07:00   88566        0.0           0.0
# 2003-01-28 00:00:00+07:00  132334        0.0           0.0

# %%
stock.financials
# Out:
#                                                               2022-12-31  \
# Tax Effect Of Unusual Items                           -5695978371.869263
# Tax Rate For Calcs                                              0.221358
# Total Unusual Items                                       -25732000000.0
# Total Unusual Items Excluding Goodwill                    -25732000000.0
# Net Income From Continuing Operation Net Minori...       3302314000000.0
# Reconciled Depreciation                                   604929000000.0
# Net Interest Income                                     14348584000000.0
# Interest Expense                                         3044747000000.0
# Interest Income                                         17393331000000.0
# Normalized Income                                   3322350021628.130859
# Net Income From Continuing And Discontinued Ope...       3302314000000.0
# Diluted Average Shares                                      9773552870.0
# ...

# %%
IC = stock.financials[stock.financials.columns[::-1]] # Reverse Column
IC
# Out:
#                                                               2019-12-31  \
# Tax Effect Of Unusual Items                           -76339722160.83342
# Tax Rate For Calcs                                                0.2951
# Total Unusual Items                                      -258691000000.0
# Total Unusual Items Excluding Goodwill                   -258691000000.0
# Net Income From Continuing Operation Net Minori...       3701125000000.0
# Reconciled Depreciation                                   422721000000.0
# Net Interest Income                                     14815737000000.0
# Interest Expense                                         7154407000000.0
# Interest Income                                         21970144000000.0
# Normalized Income                                   3883476277839.166504
# Net Income From Continuing And Discontinued Ope...       4073453000000.0
# Diluted Average Shares                                      9773552870.0
# ...

# %%
NI = IC.loc['Net Income']
NI
# Out:
# 2019-12-31    4073453000000.0
# 2020-12-31    1007614000000.0
# 2021-12-31    1573113000000.0
# 2022-12-31    3302314000000.0
# Name: Net Income, dtype: object

# %%
plt.plot(NI)
plt.xlabel('Date')
plt.ylabel('Price in millions')
plt.title('Net Income in Yearly')
# Out:
# Text(0.5, 1.0, 'Net Income in Yearly')

# %%
stock.balancesheet
# Out:
#                                                       2023-06-30  \
# Ordinary Shares Number                              7432000000.0
# Share Issued                                        7432000000.0
# Net Debt                                           12533000000.0
# Total Debt                                         59965000000.0
# Tangible Book Value                               128971000000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments  111262000000.0
# Other Short Term Investments                       76558000000.0
# Cash And Cash Equivalents                          34704000000.0
# Cash Equivalents                                   26226000000.0
# Cash Financial                                      8478000000.0
#
#                                                       2022-06-30  \
# Ordinary Shares Number                              7464000000.0
# ...

# %%
BS = stock.balancesheet.iloc[:,::-1] # Reverse Column
BS
# Out:
#                                                       2020-06-30  \
# Ordinary Shares Number                              7571000000.0
# Share Issued                                        7571000000.0
# Net Debt                                           49751000000.0
# Total Debt                                         70998000000.0
# Tangible Book Value                                67915000000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments  136527000000.0
# Other Short Term Investments                      122951000000.0
# Cash And Cash Equivalents                          13576000000.0
# Cash Equivalents                                             NaN
# Cash Financial                                               NaN
#
#                                                       2021-06-30  \
# Ordinary Shares Number                              7519000000.0
# ...

# %%
BS.loc['Retained Earnings']
# Out:
# 2020-06-30     34566000000.0
# 2021-06-30     57055000000.0
# 2022-06-30     84281000000.0
# 2023-06-30    118848000000.0
# Name: Retained Earnings, dtype: object

# %%
BS.index
# Out:
# Index(['Ordinary Shares Number', 'Share Issued', 'Net Debt', 'Total Debt',
#        'Tangible Book Value', 'Invested Capital', 'Working Capital',
#        'Net Tangible Assets', 'Capital Lease Obligations',
#        'Common Stock Equity', 'Total Capitalization',
#        'Total Equity Gross Minority Interest', 'Stockholders Equity',
#        'Gains Losses Not Affecting Retained Earnings',
#        'Other Equity Adjustments', 'Retained Earnings', 'Capital Stock',
#        'Common Stock', 'Total Liabilities Net Minority Interest',
#        'Total Non Current Liabilities Net Minority Interest',
#        'Other Non Current Liabilities', 'Tradeand Other Payables Non Current',
#        'Non Current Deferred Liabilities', 'Non Current Deferred Revenue',
#        'Non Current Deferred Taxes Liabilities',
#        'Long Term Debt And Capital Lease Obligation',
#        'Long Term Capital Lease Obligation', 'Long Term Debt',
#        'Current Liabilities', 'Other Current Liabilities',
# ...

# %%
BS.loc['Total Assets'] / BS.loc['Current Liabilities']
# Out:
# 2020-06-30    4.166934
# 2021-06-30    3.764835
# 2022-06-30    3.837109
# 2023-06-30     3.95564
# dtype: object
